# %%
#%pip install nba_api
#!pip install "fastapi[all]"
#!pip install uvicorn[standard]

# %%
from nba_api.stats.endpoints import leaguegamefinder
import pandas as pd
import numpy as np

# %%
from fastapi import FastAPI

# %%
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/31/2022', league_id_nullable='00')
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0     22022  1610612760               OKC  Oklahoma City Thunder  0022200611
# 1     22022  1610612744               GSW  Golden State Warriors  0022200615
# 2     22022  1610612739               CLE    Cleveland Cavaliers  0022200614
# 3     22022  1610612766               CHA      Charlotte Hornets  0022200613
# 4     22022  1610612748               MIA             Miami Heat  0022200611
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2023-01-10    OKC @ MIA  L  241  111  ...   0.667    14    30   44   27
# 1  2023-01-10  GSW vs. PHX  L  241  113  ...   0.778    16    29   45   24
# 2  2023-01-10    CLE @ UTA  L  240  114  ...   0.833     7    30   37   18
# 3  2023-01-10    CHA @ TOR  L  240  120  ...   0.733     6    28   34   33
# 4  2023-01-10  MIA vs. OKC  W  239  112  ...   1.000    13    28   41   18
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    8    3   18  27        -1.0
# 1   13    2   15  26       -12.0
# 2    7    7    5  25        -2.0
# 3    6    4    9  19       -12.0
# 4   10    4   19  19         1.0
#
# [5 rows x 28 columns]

# %%
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2530 entries, 0 to 2529
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TEAM_NAME   2530 non-null   object
#  1   GAME_ID     2530 non-null   object
#  2   GAME_DATE   2530 non-null   object
#  3   MATCHUP     2530 non-null   object
#  4   WL          2530 non-null   object
#  5   PLUS_MINUS  2530 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 118.7+ KB

# %%
#convert game date to app. format
import pandas as pd
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

# %%
#feature engineering to create a new variable for last 30 game performance
games['avg_30_plus_minus'] = games.groupby('TEAM_NAME')['PLUS_MINUS'].transform(lambda x: x.rolling(30, closed='left').mean())

# %%
#Toronto Raptors games
games[games['TEAM_NAME']=='Toronto Raptors'].head(35)
# Out:
#             TEAM_NAME     GAME_ID  GAME_DATE      MATCHUP WL  PLUS_MINUS  \
# 10    Toronto Raptors  0022200613 2023-01-10  TOR vs. CHA  W        12.0
# 41    Toronto Raptors  0022200597 2023-01-08  TOR vs. POR  W        12.0
# 61    Toronto Raptors  0022200582 2023-01-06  TOR vs. NYK  L        -4.0
# 102   Toronto Raptors  0022200569 2023-01-04  TOR vs. MIL  L        -3.0
# 126   Toronto Raptors  0022200553 2023-01-02    TOR @ IND  L        -8.0
# 174   Toronto Raptors  0022200531 2022-12-30  TOR vs. PHX  W        12.0
# 183   Toronto Raptors  0022200526 2022-12-29  TOR vs. MEM  L       -13.0
# 215   Toronto Raptors  0022200509 2022-12-27  TOR vs. LAC  L       -11.0
# 264   Toronto Raptors  0022200484 2022-12-23    TOR @ CLE  W        11.0
# 299   Toronto Raptors  0022200471 2022-12-21    TOR @ NYK  W         7.0
# 330   Toronto Raptors  0022200453 2022-12-19    TOR @ PHI  L        -3.0
# 335   Toronto Raptors  0022200448 2022-12-18  TOR vs. GSW  L       -16.0
# 365   Toronto Raptors  0022200433 2022-12-16  TOR vs. BKN  L        -3.0
# 405   Toronto Raptors  0022200417 2022-12-14  TOR vs. SAC  L        -1.0
# 441   Toronto Raptors  0022200398 2022-12-11    TOR @ ORL  L       -12.0
# 469   Toronto Raptors  0022200379 2022-12-09    TOR @ ORL  L        -4.0
# 499   Toronto Raptors  0022200366 2022-12-07  TOR vs. LAL  W        13.0
# 522   Toronto Raptors  0022200355 2022-12-05  TOR vs. BOS  L        -6.0
# 560   Toronto Raptors  0022200340 2022-12-03  TOR vs. ORL  W        13.0
# 566   Toronto Raptors  0022200329 2022-12-02    TOR @ BKN  L        -9.0
# 586   Toronto Raptors  0022200318 2022-11-30    TOR @ NOP  L       -18.0
# 630   Toronto Raptors  0022200303 2022-11-28  TOR vs. CLE  W        12.0
# 659   Toronto Raptors  0022200286 2022-11-26  TOR vs. DAL  W         5.0
# 715   Toronto Raptors  0022200266 2022-11-23  TOR vs. BKN  L       -14.0
# 756   Toronto Raptors  0022200235 2022-11-19    TOR @ ATL  L        -2.0
# 808   Toronto Raptors  0022200215 2022-11-16  TOR vs. MIA  W         8.0
# 826   Toronto Raptors  0022200199 2022-11-14    TOR @ DET  W         4.0
# 863   Toronto Raptors  0022200187 2022-11-12    TOR @ IND  L       -14.0
# 871   Toronto Raptors  0022200179 2022-11-11    TOR @ OKC  L       -19.0
# 914   Toronto Raptors  0022200165 2022-11-09  TOR vs. HOU  W         7.0
# 925   Toronto Raptors  0022200151 2022-11-07    TOR @ CHI  L       -14.0
# 950   Toronto Raptors  0022200141 2022-11-06  TOR vs. CHI  W         9.0
# 972   Toronto Raptors  0022200127 2022-11-04    TOR @ DAL  L        -1.0
# 1003  Toronto Raptors  0022200114 2022-11-02    TOR @ SAS  W        43.0
# 1031  Toronto Raptors  0022200099 2022-10-31  TOR vs. ATL  W        30.0
#
#       avg_30_plus_minus
# 10                  NaN
# 41                  NaN
# 61                  NaN
# 102                 NaN
# 126                 NaN
# 174                 NaN
# 183                 NaN
# 215                 NaN
# 264                 NaN
# 299                 NaN
# 330                 NaN
# 335                 NaN
# 365                 NaN
# 405                 NaN
# 441                 NaN
# 469                 NaN
# 499                 NaN
# 522                 NaN
# 560                 NaN
# 566                 NaN
# 586                 NaN
# 630                 NaN
# 659                 NaN
# 715                 NaN
# 756                 NaN
# 808                 NaN
# 826                 NaN
# 863                 NaN
# 871                 NaN
# 914                 NaN
# 925           -1.466667
# 950           -2.333333
# 972           -2.433333
# 1003          -2.333333
# 1031          -0.800000

# %%
#feature engeering to create variable for home & away games
msk = games['MATCHUP'].str.contains('@')
games_away = games[msk]
games_home = games[~msk]

# %%
#merging duplicate entries 
games_merged = pd.merge(games_home, games_away, on='GAME_ID', suffixes=('_home', '_away'))

# %%
#feature engineering to create a new variable
games_merged['avg_30_plus_minus_diff'] = games_merged['avg_30_plus_minus_home'] - games_merged['avg_30_plus_minus_away']

# %%
games_merged[['WL_home', 'avg_30_plus_minus_diff']]
# Out:
#      WL_home  avg_30_plus_minus_diff
# 0          L                     NaN
# 1          W                     NaN
# 2          W                     NaN
# 3          L                     NaN
# 4          W                     NaN
# ...      ...                     ...
# 1260       W                7.900000
# 1261       L               -8.500000
# 1262       W               -8.733333
# 1263       W               -6.300000
# 1264       W                8.800000
#
# [1265 rows x 2 columns]

# %%
#mapping 1 and 0 for the variables
games_model = games_merged[['WL_home', 'avg_30_plus_minus_diff']].dropna()
games_model['WL_home'] = games_model['WL_home'].map({'W': 1, 'L': 0})

# %% [markdown]
# ## Developing hypertuned prediction model

# %%
#importing library and creating train-test split
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(games_model, stratify=games_model['WL_home'], test_size=0.2, random_state=7)

# %%
#assigning values in train & test dataset
target = 'WL_home'
X_train = df_train.drop(columns=target)
y_train = df_train[target]

X_test = df_test.drop(columns=target)
y_test= df_test[target]

# %%
#using Xgboost for calcuation
import xgboost as xgb
clf = xgb.XGBClassifier(use_label_encoder=False, random_state=7)
clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=7,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
#predicting values based on test values
from sklearn.metrics import accuracy_score
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.559748427672956

# %%
#hyperparam tuning to improve performance
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.fixes import loguniform

hyp_params = {'learning_rate': loguniform(0.0001, 1),
              'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
              'subsample': [0.7, 0.8, 0.9, 1.0],
              'n_estimators': [50, 100, 150, 200]}


random_hyp = RandomizedSearchCV(estimator=clf, 
                                param_distributions=hyp_params, 
                                n_iter=20, 
                                cv=7,
                                scoring='accuracy',
                                random_state=7)

# %%
#fiting the model on test data
random_hyp.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=7,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            callbacks=None, colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, gamma=0, gpu_id=-1,
#                                            grow_policy='depthwise',
#                                            importance_type=None,
#                                            interaction_constraints='',
#                                            learning_rate=0.300000012,
#                                            max_bin=256,...
#                                            n_estimators=100, n_jobs=0,
#                                            num_parallel_tree=1,
#                                            predictor='auto', random_state=7,
#                                            reg_alpha=0, reg_lambda=1, ...),
#                    n_iter=20,
#                    param_distributions={'learning_rate': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000002943E2225E0>,
#                                         'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
#                                         'n_estimators': [50, 100, 150, 200],
#                                         'subsample': [0.7, 0.8, 0.9, 1.0]},
#                    random_state=7, scoring='accuracy')

# %%
#finding best params
random_hyp.best_params_
# Out:
# {'learning_rate': 0.025246179740589205,
#  'max_depth': 2,
#  'n_estimators': 150,
#  'subsample': 0.7}

# %%
#fitting the new model on test data
model_hyp = random_hyp.best_estimator_
y_pred_hyp = model_hyp.predict(X_test)
accuracy_score(y_test, y_pred_hyp)
# Out:
# 0.5408805031446541

# %% [markdown]
# ## Saving the predictive model

# %%
#creating model file
from joblib import dump, load
dump(model_hyp, 'model_nba.joblib') 
model_saved = load('model_nba.joblib')

# %%
#checking the accuracy
accuracy_score(y_test, model_saved.predict(X_test))
# Out:
# 0.5408805031446541

# %%
team_home='Toronto Raptors'
team_away='Brooklyn Net'

import numpy as np
gamefinder = leaguegamefinder.LeagueGameFinder(date_from_nullable='01/01/2021',
                                           league_id_nullable='00')
games = gamefinder.get_data_frames()[0]
games = games[['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

msk_home = (games['TEAM_NAME'] == team_home)
games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
home_plus_minus = games_30_home['PLUS_MINUS'].mean()

msk_away = (games['TEAM_NAME'] == team_away)
games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
away_plus_minus = games_30_away['PLUS_MINUS'].mean()

games_diff=home_plus_minus - away_plus_minus

predict_home_win=model_saved.predict(np.array([games_diff]))[0]
predict_winning_probability=model_saved.predict_proba(np.array([games_diff]))[0][1]

# %%
#creating a function to intake team names & predicting the win probability
## 1 is home team win, 0 is away team win. 
## 

def predict_games(team_home, team_away):
    gamefinder = leaguegamefinder.LeagueGameFinder(
        date_from_nullable='01/01/2021',
        league_id_nullable='00')
    games = gamefinder.get_data_frames()[0]
    games = games[
        ['TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'PLUS_MINUS']]
    games['GAME_DATE'] = pd.to_datetime(games['GAME_DATE'])

    msk_home = (games['TEAM_NAME'] == team_home)
    games_30_home = games[msk_home].sort_values('GAME_DATE').tail(30)
    home_plus_minus = games_30_home['PLUS_MINUS'].mean()

    msk_away = (games['TEAM_NAME'] == team_away)
    games_30_away = games[msk_away].sort_values('GAME_DATE').tail(30)
    away_plus_minus = games_30_away['PLUS_MINUS'].mean()

    games_diff = home_plus_minus - away_plus_minus

    predict_home_win = model_saved.predict(np.array([games_diff]))[0]
    predict_winning_probability = model_saved.predict_proba(np.array([games_diff]))[0][1]
    return predict_home_win, predict_winning_probability

# %%
predict_games('Toronto Raptors','Brooklyn Nets')
# Out:
# (0, 0.42692325)
